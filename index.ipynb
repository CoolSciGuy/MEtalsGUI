# %% [markdown]
# # <div style="text-align: center"> Welcome to DOEE's Water quality viewing tool

# %% [markdown]
# ![DOEE.ico](attachment:DOEE.ico)

# %% [markdown]
# To see individual WQ charts and graphs, click on the line bellow and hit Shift+enter.

# %%
run GUI

# %% [markdown]
# To see comparitive WQ charts and graphs, click on the line bellow and hit Shift+enter. Select Mutiple stations.

# %%
run GUI2

# %% [markdown]
# To see comparitive WQ charts and graphs, click on the line bellow and hit Shift+enter. Select Mutiple stations.

# %%
run GUI3
# Out:
# SEJveChjaGlsZHJlbj0oU2VsZWN0TXVsdGlwbGUoZGVzY3JpcHRpb249dSdTdGF0aW9ucycsIGluZGV4PSgxLCAyKSwgb3B0aW9ucz0oJ0FsbCBTdGF0aW9ucycsICdBbmFjb3N0aWEgTWFpbnPigKY=
# Output()

# %% [markdown]
# ![Stations.jpg](attachment:Stations.jpg)

# %%
autoscroll_starting_threshold
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ed165f7c695b> in <module>()
# ----> 1 autoscroll_starting_threshold
#
# NameError: name 'autoscroll_starting_threshold' is not defined
